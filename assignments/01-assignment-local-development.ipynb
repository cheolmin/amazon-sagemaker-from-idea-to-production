# %% [markdown]
# # 과제 1: 노트북에서 로컬 개발
# 이 과제에서는 데이터 처리, 피처 엔지니어링, 모델 훈련 및 테스트 데이터셋에서 모델 평가를 수행하는 코드를 작성합니다. 모든 처리를 로컬 노트북에서 수행하며, 확장성과 재현성을 빠른 배포 속도 및 다양한 피처 엔지니어링 접근법과 모델 유형을 실험하기 위한 빠른 반복으로 교환합니다.
#
# 선택적으로 이 노트북을 SageMaker 온디맨드 또는 예약된 노트북 작업으로 헤드리스 방식으로 실행할 수 있습니다.
#
# 이 과제의 코드 스니펫과 일반적인 지침은 [`01-idea-development.ipynb`](../01-idea-development.ipynb) 노트북을 참조하세요.
#
# 자유롭게 자신의 데이터셋과 모델로 특정 사용 사례를 구현할 수 있습니다.

# %% [markdown]
# ## 패키지 설치 및 임포트
# 노트북 커널에 패키지를 설치하려면 `%` 명령과 `pip install`을 사용할 수 있습니다.

# %%
# %pip install --upgrade pip
# %pip install -q  xgboost sagemaker-experiments

# %%
import pandas as pd
import numpy as np 
import json
import joblib
import xgboost as xgb
import sagemaker
import boto3
import os
from time import gmtime, strftime, sleep
from sklearn.metrics import roc_auc_score
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker

sagemaker.__version__

# %%
session = sagemaker.Session()
sm = session.sagemaker_client

# %% [markdown]
# ## 데이터 로드
# - 파일 이름과 경로와 같은 리터럴 상수를 보관할 변수 생성
# - 로컬 파일에서 Pandas 데이터프레임으로 데이터 로드
# - 데이터 탐색

# %%
# 데이터 로드 코드 작성

# %% [markdown]
# ## [선택사항] 실험 생성
# [Amazon SageMaker Experiments Python SDK](https://sagemaker-experiments.readthedocs.io/en/latest/)를 사용하여 실험을 생성하고 관리합니다.

# %%
# 실험 생성 코드 작성

# %% [markdown]
# ## 연습 1: EDA 및 피처 엔지니어링
# - 데이터 처리 구현
# - EDA 구현
# - 피처 엔지니어링 구현

# %%
# 연습 1 - 여기에 코드 작성

# %% [markdown]
# ## 연습 2: 데이터 분할
# - 훈련을 위한 데이터 준비, 데이터셋 분할

# %%
# 연습 2 - 여기에 코드 작성
# train_data, validation_data, test_data = np.split()

# %% [markdown]
# ## 연습 3: 모델 훈련
# - 모델 훈련
# - 선택사항: 모델 훈련 실행을 시행(trial) 및 시행 구성요소(trial component)로 추적

# %%
# 연습 3 - 여기에 코드 작성

# %% [markdown]
# ## 연습 4: 모델 검증
# - 테스트 데이터셋에서 모델 검증

# %%
# 연습 4 - 여기에 코드 작성

# test_auc = roc_auc_score(test_label, test_pred)
# train_auc = roc_auc_score(train_label, train_pred)
# print(f"Train-auc:{train_auc:.2f}, Test-auc:{test_auc:.2f}")

# %% [markdown]
# ## 연습 5: [선택사항] Studio에서 실험 탐색
# 실험 및 시행 작업 방법을 이해하려면 [View and Compare Amazon SageMaker Experiments, Trials, and Trial Components](https://docs.aws.amazon.com/sagemaker/latest/dg/experiments-view-compare.html) 개발자 가이드를 참조하세요.

# %% [markdown]
# ## 연습 6: [선택사항] 노트북을 SageMaker 작업으로 실행
# 노트북 코드를 조정하고 [Notebook-based Workflows](https://docs.aws.amazon.com/sagemaker/latest/dg/notebook-auto-run.html)의 지침에 따라 이 노트북을 온디맨드 헤드리스 SageMaker 작업으로 실행하세요.

# %% [markdown]
# ## 과제 2 계속하기
# [과제 2](02-assignment-sagemaker-containers.ipynb) 노트북으로 이동하세요.
