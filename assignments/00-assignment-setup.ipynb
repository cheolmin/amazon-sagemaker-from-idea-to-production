# %% [markdown]
# # 과제: 설정
# 이 노트북 시리즈는 Amazon SageMaker MLOps 구성 요소를 사용하여 ML 개발 프로세스를 따라가는 동안 과제를 안내합니다.
#
# 과제는 제공된 노트북을 기반으로 하며, 노트북의 코드를 사용하여 연습 문제를 완료할 수 있습니다.
#
# 이 과제의 코드 스니펫과 일반적인 지침은 [`00-start-here.ipynb`](../00-start-here.ipynb) 노트북을 참조하세요.

# %% [markdown]
# ## 패키지 임포트

# %%
import time
import os
import json
import boto3
import numpy as np  
import pandas as pd 
import sagemaker

sagemaker.__version__

# %% [markdown]
# ## 연습 1: AWS 및 SageMaker 환경
# - [sagemaker session](https://sagemaker.readthedocs.io/en/stable/api/utility/session.html) 인스턴스화
# - Amazon SageMaker 상호 작용에 사용할 기본 버킷의 이름 가져오기
# - SageMaker 실행 역할 가져오기
# - AWS 리전 가져오기
# - boto3 [sagemaker client](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/sagemaker.html) 인스턴스화

# %%
# 연습 1 - 여기에 코드 작성

# %% [markdown]
# ## 연습 2: Studio 환경
# - 노트북 메타데이터 파일 `/opt/ml/metadata/resource-metadata.json` 탐색
# - SageMaker `domain_id` 가져오기
# - Studio 사용자 프로필 이름 가져오기
# - 노트북 이미지 이름 가져오기

# %%
# 연습 2 - 여기에 코드 작성
NOTEBOOK_METADATA_FILE = "/opt/ml/metadata/resource-metadata.json"

# %% [markdown]
# ## 연습 3: 데이터
# - 데이터셋 다운로드. 로컬 저장소나 인터넷에서 자신의 데이터셋을 다운로드할 수 있습니다
# - Pandas 데이터프레임으로 데이터를 로드하고 데이터 확인

# %%
# !wget -P data/ -N https://archive.ics.uci.edu/ml/machine-learning-databases/00222/bank-additional.zip

# %%
# 연습 3 - 여기에 코드 작성
# df_data = pd.read_csv()

# %% [markdown]
# ## 과제 1 계속하기
# [과제 1](01-assignment-local-development.ipynb) 노트북으로 이동하세요.
